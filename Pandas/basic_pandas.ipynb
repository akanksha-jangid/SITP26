# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ***Pandas***
#
# Pandas is a powerful Python library used for:
#
# * Data analysis
# * Data cleaning
# * Working with tables (Excel/CSV data)
# * Handling large datasets
#
# It is one of the most important libraries in:
#
# * Data Science
# * Machine Learning
# * AI
# * Data Analytics

# %%
import os
import numpy as np
import pandas as pd

# %%
#######df=data frame

# %%
df=pd.read_csv(r"C:\Users\Hp\Downloads\Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.tail(15)
# Out:
#                              bike_name     price                 city  \
# 32633      Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32634  Royal Enfield Thunderbird 350cc   70000.0               Mumbai
# 32635                Suzuki Zeus 125cc   35000.0            Ahmedabad
# 32636                     KTM RC 390cc  196700.0               Mumbai
# 32637               Bajaj Pulsar 150cc   25000.0                Delhi
# 32638            Yamaha Fazer 25 250cc  123000.0               Kadapa
# 32639      Royal Enfield Classic 350cc   95500.0                Delhi
# 32640           Hero Passion Pro 100cc   32000.0                Delhi
# 32641              Bajaj Avenger 220cc   41000.0                Delhi
# 32642               Hero Passion 100cc   15000.0          Perumbavoor
# 32643           Hero Passion Pro 100cc   39000.0                Delhi
# 32644             TVS Apache RTR 180cc   30000.0               Karnal
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  str
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  str
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  str
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  str
# dtypes: float64(4), str(4)
# memory usage: 2.0 MB

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='str')

# %%
df["age"]
# Out:
# 0         3.0
# 1         4.0
# 2         8.0
# 3         4.0
# 4         3.0
#          ...
# 32643     4.0
# 32644     9.0
# 32645     6.0
# 32646    16.0
# 32647    13.0
# Name: age, Length: 32648, dtype: float64

# %%
df[["age"]]
# Out:
#         age
# 0       3.0
# 1       4.0
# 2       8.0
# 3       4.0
# 4       3.0
# ...     ...
# 32643   4.0
# 32644   9.0
# 32645   6.0
# 32646  16.0
# 32647  13.0
#
# [32648 rows x 1 columns]

# %%
df[["age","price"]]
# Out:
#         age     price
# 0       3.0   35000.0
# 1       4.0  119900.0
# 2       8.0  600000.0
# 3       4.0   65000.0
# 4       3.0   80000.0
# ...     ...       ...
# 32643   4.0   39000.0
# 32644   9.0   30000.0
# 32645   6.0   60000.0
# 32646  16.0   15600.0
# 32647  13.0   22000.0
#
# [32648 rows x 2 columns]

# %%
df["brand"].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df["owner"].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df["city"].unique()
# Out:
# <StringArray>
# [   'Ahmedabad',        'Delhi',    'Bangalore',       'Mumbai',
#        'Kalyan',    'Faridabad',       'Mettur',    'Hyderabad',
#       'Kaithal',      'Gurgaon',
#  ...
#   'Bhubaneswar',      'Raiganj', 'Bhilai Nagar',       'Baloda',
#      'Anantnag',   'Berhampore',      'Silvasa',       'Hospet',
#         'Palai',        'Sidhi']
# Length: 443, dtype: str

# %%
df["brand"].nunique()
# Out:
# 23

# %%
df["brand"].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# LML                    1
# Yezdi                  1
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643     True
# 32644     True
# 32645     True
# 32646     True
# 32647     True
# Length: 32648, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates() ###duplicate ko drop krne k liye kaam aati hai
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.duplicated().sum() ####total duplicate value
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True) ####deplicate row ko permanently delete kr deta hai

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.dropna(inplace = True) ######dropna is used to drop null values

# %%
# y = mx +c linear regression

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 7324 entries, 0 to 9372
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   7324 non-null   str
#  1   price       7324 non-null   float64
#  2   city        7324 non-null   str
#  3   kms_driven  7324 non-null   float64
#  4   owner       7324 non-null   str
#  5   age         7324 non-null   float64
#  6   power       7324 non-null   float64
#  7   brand       7324 non-null   str
# dtypes: float64(4), str(4)
# memory usage: 515.0 KB

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
####decoding :int ko string m convert krna 
####encoding : string ko int m convert krna

# %%
# owner_dict ={
#     'First Owner':1, 'Second Owner':2, 'Third Owner':3, 'Fourth Owner Or More':4
# }

# %%
# df['owner']=df['owner'].map(owner_dict)##map function used for mapping

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# df.info() #######encoding hui hai

# %%
# df.drop('city',axis=1,inplace=True)#axis=1 ka meaning cloumn #axis=0 meaning row
####column permanent delete yah drop krna

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# df.drop(['age','bike_name'],axis=1,inplace=True)

# %%
# df

# %%
# df['brand'].unique()

# %%
# df.info()

# %%
# df

# %%
# df['brand']=df['brand'].map(brand_dict)

# %%
# df

# %%
# df.info()

# %%
obj_val=df.select_dtypes(include='O')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19464\3000755879.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   obj_val=df.select_dtypes(include='O')

# %%
obj_val
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand
# 0                 TVS
# 1       Royal Enfield
# 2             Triumph
# 3                 TVS
# 4              Yamaha
# ...

# %%
num=df.select_dtypes(exclude='O')

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
num
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
complete_data=pd.concat([obj_val , num] , axis=1)

# %%
complete_data
# Out:
#                                  bike_name       city        owner  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1              Royal Enfield Classic 350cc      Delhi  First Owner
# 2                     Triumph Daytona 675R      Delhi  First Owner
# 3                     TVS Apache RTR 180cc  Bangalore  First Owner
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                    ...        ...          ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi  First Owner
# 9369                   Bajaj Avenger 220cc  Bangalore  First Owner
# 9370        Harley-Davidson Street 750 ABS    Jodhpur  First Owner
# 9371                 Bajaj Dominar 400 ABS  Hyderabad  First Owner
# 9372              Bajaj Avenger Street 220  Hyderabad  First Owner
#
#                 brand     price  kms_driven  age  power
# 0                 TVS   35000.0     17654.0  3.0  110.0
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df[df['brand']=='TVS']
# Out:
#                                bike_name    price       city  kms_driven  \
# 0     TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                   TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                  TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114           TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130               TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                  ...      ...        ...         ...
# 9247      TVS Apache RTR 160cc Rear Disc  70000.0  Ghaziabad      4116.0
# 9307                TVS Apache RTR 160cc  30000.0     Alibag     30000.0
# 9312            TVS Apache RTR 200 4V FI  65450.0      Delhi      9238.0
# 9320                    TVS Apache 150cc  20000.0     Hissar     84916.0
# 9322           TVS Radeon 110cc Drum SBT  58000.0      Delhi      4020.0
#
#             owner   age  power brand
# 0     First Owner   3.0  110.0   TVS
# ...

# %%
# dup>null value >str>num>drop

# %%
# df.isnull().sum()

# %%
# df.info()

# %%
# df.dropna(inplace=True)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# df.info()

# %%
# df['bike_name'].unique()

# %%
bike_name_dict={
    'TVS Star City Plus Dual Tone 110cc':1,
              'Royal Enfield Classic 350cc':2,
                     'Triumph Daytona 675R':3,
                     'TVS Apache RTR 180cc':4,
     'Yamaha FZ S V 2.0 150cc-Ltd. Edition':5,
                         'Yamaha FZs 150cc':6,
            'Honda CB Hornet 160R  ABS DLX':7,
      'Hero Splendor Plus Self Alloy 100cc':8,
        'Royal Enfield Thunderbird X 350cc':9,
 'Royal Enfield Classic Desert Storm 500cc':10,
 
                 'Bajaj Discover150S 150cc':11,
                       'Hero i Smart 125cc':12,
               'Hero Splendor Plus  100 cc':13,
                'Hero Splendor Plus 100 CC':14,
                      'Hero Karizma 223 cc':15,
                         'TVS MAX 4R 110cc':16,
                   'Mahindra Pantero 110cc':17,
                      'Hero Ambition 135cc':18,
                'Honda CBR 250R Repsol ABS':19,
                'Hero Hunk Rear Disc 150cc':20
             
}

# %%
# df['bike_name']= df['bike_name'].map(bike_name_dict)

# %%
# df

# %%
# df.info()

# %%
# df.dropna().sum()

# %%
# df.isnull().sum()

# %%
# df.dropna(inplace=True)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
# df.isnull().sum()

# %%
# df.info()

# %%
# df.drop('bike_name',axis=1,inplace=True)

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
tvs_brand=df[df['brand']=='TVS']

# %%
tvs_under2 =tvs_brand[tvs_brand['age']<=2]

# %%
tvs_under2[tvs_under2['kms_driven']<2000]
# Out:
#                                        bike_name     price       city  \
# 594               TVS Apache RTR 160 4V DISC ABS   91800.0      Delhi
# 1126  TVS Apache RTR 200 4V Dual Channel ABS BS6  130000.0  Bangalore
# 1132          TVS Apache RTR 160 4V DISC ABS BS6   98000.0     Jaipur
# 1318      TVS Apache RTR 200 4V ABS Race Edition  125000.0  Hyderabad
# 1802                        TVS Apache RTR 180cc   88000.0    Gurgaon
# 3071              TVS Apache RTR 160 4V DISC ABS   94000.0  Ahmedabad
# 5506      TVS Apache RTR 200 4V ABS Race Edition  106000.0      Delhi
# 6003            TVS Apache RTR 160 4V Carburetor   90700.0      Delhi
#
#       kms_driven        owner  age  power brand
# 594       1050.0  First Owner  2.0  160.0   TVS
# 1126      1300.0  First Owner  1.0  200.0   TVS
# 1132       749.0  First Owner  1.0  160.0   TVS
# 1318       530.0  First Owner  2.0  200.0   TVS
# 1802       900.0  First Owner  2.0  180.0   TVS
# ...

# %%
royal_enfield_brand=df[df['brand']=='Royal Enfield']

# %%
royal_enfield_under2=royal_enfield_brand[royal_enfield_brand['age']<=2]

# %%
royal_enfield_under2[royal_enfield_under2['kms_driven']<2000]
# Out:
#                                               bike_name     price       city  \
# 277                     Royal Enfield Interceptor 650cc  280000.0  Bangalore
# 850                Royal Enfield Himalayan 410cc Fi ABS  180000.0   Guwahati
# 962               Royal Enfield Thunderbird X 350cc ABS  155000.0   Vadodara
# 1203      Royal Enfield Classic Gunmetal Grey 350cc ABS  150000.0  Bardhaman
# 1251                    Royal Enfield Interceptor 650cc  250000.0    Silchar
# 1716                Royal Enfield Thunderbird 350cc ABS  144700.0     Kharar
# 1796               Royal Enfield Himalayan 410cc Fi ABS  166000.0   Guwahati
# 2929               Royal Enfield Himalayan 410cc Fi ABS  184000.0  Bardhaman
# 3089  Royal Enfield Classic Desert Storm 500cc Dual ...  239000.0     Mumbai
# 3166              Royal Enfield Thunderbird X 350cc ABS  160000.0      Delhi
# 5133              Royal Enfield Thunderbird X 350cc ABS  170000.0    Gurgaon
# ...

# %%
royal_enfield_under2[royal_enfield_under2['price']<150000]
# Out:
#                                              bike_name     price       city  \
# 194                        Royal Enfield Electra 350cc  145000.0  Bangalore
# 1006               Royal Enfield Thunderbird 350cc ABS  148000.0   Haldwani
# 1681             Royal Enfield Thunderbird X 350cc ABS  135000.0   Sibsagar
# 1716               Royal Enfield Thunderbird 350cc ABS  144700.0     Kharar
# 1749    Royal Enfield Bullet Twinspark Kickstart 350cc  145000.0      Delhi
# 2982      Royal Enfield Classic 350cc-Redditch Edition  137000.0  Sultanpur
# 5939    Royal Enfield Bullet Twinspark Kickstart 350cc  105000.0  Faridabad
# 6090  Royal Enfield Bullet Electra Twinspark 350CC ABS  127000.0     Mumbai
# 6298  Royal Enfield Bullet Electra Twinspark 350CC ABS  140000.0     Mumbai
# 6329                       Royal Enfield Electra 350cc  130000.0  Faridabad
# 6590                       Royal Enfield Classic 350cc  130000.0  Ghaziabad
# ...

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
df[(df['brand']=='Royal Enfield') & (df["age"]<=2) & (df['price']<=150000)]
# Out:
#                                              bike_name     price       city  \
# 194                        Royal Enfield Electra 350cc  145000.0  Bangalore
# 479                        Royal Enfield Classic 350cc  150000.0      Delhi
# 1006               Royal Enfield Thunderbird 350cc ABS  148000.0   Haldwani
# 1203     Royal Enfield Classic Gunmetal Grey 350cc ABS  150000.0  Bardhaman
# 1681             Royal Enfield Thunderbird X 350cc ABS  135000.0   Sibsagar
# 1716               Royal Enfield Thunderbird 350cc ABS  144700.0     Kharar
# 1749    Royal Enfield Bullet Twinspark Kickstart 350cc  145000.0      Delhi
# 2982      Royal Enfield Classic 350cc-Redditch Edition  137000.0  Sultanpur
# 5495                       Royal Enfield Classic 350cc  150000.0       Kota
# 5939    Royal Enfield Bullet Twinspark Kickstart 350cc  105000.0  Faridabad
# 6090  Royal Enfield Bullet Electra Twinspark 350CC ABS  127000.0     Mumbai
# ...

# %%
df.query("brand=='Royal Enfield' and age <=2")
# Out:
#                                          bike_name     price          city  \
# 38               Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 81                 Royal Enfield Interceptor 650cc  260000.0   Navi Mumbai
# 139           Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194                    Royal Enfield Electra 350cc  145000.0     Bangalore
# 222           Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                            ...       ...           ...
# 7294  Royal Enfield Classic 350cc-Redditch Edition  133500.0        Mumbai
# 7694        Royal Enfield Classic Chrome 500cc ABS  215000.0         Delhi
# 8139         Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192           Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836         Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# ...

# %%
x=df.drop('price',axis=1)

# %%
y=df[['price']]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7324 rows x 1 columns]

# %%
x
# Out:
#                                  bike_name       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc      Delhi     11000.0
# 2                     Triumph Daytona 675R      Delhi       110.0
# 3                     TVS Apache RTR 180cc  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore     10000.0
# ...                                    ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220  Hyderabad      7127.0
#
#             owner  age  power            brand
# 0     First Owner  3.0  110.0              TVS
# 1     First Owner  4.0  350.0    Royal Enfield
# ...

# %%
df.to_csv("clean_bike_data.csv")

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df=pd.read_csv(r"C:\Users\Hp\AppData\Local\Packages\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\LocalState\sessions\1A888A513422D7B9363EF4B2C96604499E1209F7\transfers\2026-23\cust_satisfaction.csv")

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...
