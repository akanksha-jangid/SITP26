# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Hp\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=8 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Hp\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Hp\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Hp\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(data['total_bill'])
plt.show()

# %%
sns.lineplot(data['total_bill'])
plt.show()

# %%
plt.scatter(data['total_bill'],data['tip'])
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=data)
plt.show()

# %%
plt.hist(data['total_bill'])
plt.show()

# %%
sns.histplot(data['total_bill'])
plt.show()

# %%
sns.kdeplot(data['total_bill'])
plt.show()

# %%
# catplot and relplot
sns.relplot(x='total_bill',y="tip",data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y="tip",hue='time',data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y="tip",hue='smoker',data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y="tip",hue='time',kind='scatter',col='smoker',data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y="tip",hue='time',kind='scatter',row='smoker',data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y="tip",hue='time',kind='scatter',col='day',data=data)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=data)
plt.title("This is scatter plot")
plt.xlabel('total_bill',fontsize=20,color='black')
plt.ylabel
plt.show()

# %%
sns.catplot(x="day",y='total_bill',kind='swarm',data=data)
plt.show()

# %%
sns.catplot(x="day",y='total_bill',kind='boxen',data=data)
plt.show()

# %%
sns.catplot(x="day",y='total_bill',kind='point',data=data)
plt.show()

# %%
sns.catplot(x="day",y='total_bill',kind='violin',data=data)
plt.show()
