# %% [markdown]
# ***FUNCTION***
# Functions are the block of code that are used to perform a specific task
# Functions are of two type
# * **pre-defined function**
# * print()
# * len()
# * max()
# * min()
# * type()
# * sum()
# * input()
# * **user-defined function**
# These function are created by user ,using ***def*** keyword

# %% [markdown]
# ***pass*** if a placeholder key word

# %%
def function_name():
    pass
###def keyword
###

# %%
###during drfining thr function 1st letter should be small
def temp():
    print("Welcome to python")
temp() ###function calling
# Out:
# Welcome to python

# %% [markdown]
# ***framework***

# %%
temp()
# Out:
# Welcome to python

# %%
def add():
    a = 10
    b = 20
    print(a+b)
add()
# Out:
# 30

# %%
def add(a,b): ##paraments
    print(a+b)
add(a= 10, b =50)##arguments
# Out:
# 60

# %%
def square(a,b): ##paraments
    print(a**b)
square(a=9 , b=2)
# Out:
# 81

# %%
def add(a,b): ##paraments
    return(a+b)
add(a= 10, b =50)##arguments
# Out:
# 60

# %%
lst=[1,2,3,4,5,6,7,8,9,9,4]
def even(lst):
    print(lst)
    for x in lst:
        if x %2==0:
            print(x, "is even")
        else:
            print(x, "is odd")

lst=[1,2,3,4,5,6,7,8,9,9,4]
even(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 9, 4]
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 9 is odd
# 4 is even

# %%
def prime():
    
    for x in range(1,101):
        if x>1:
            for i in range(2,x):
                if x% i ==0:
                    break
        
        else:
            print(x)


            
        

prime()
# Out:
# 1

# %%
print()
