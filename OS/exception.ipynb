# %%
try:
    pass
except:
    pass
else:
    pass
finally:
    pass

# %%
a=10
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 a=10
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# solution of Zero division error

# %%
try:
    a=10
    b=0
    print(a/b)
except ZeroDivisionError as e:
    print(e)
except ValueError as e:
    print(e)
# Out:
# division by zero

# %%
try:
    a=int(input("enter first number"))
    b=int(input("enter second number"))
    print(a/b)
except ZeroDivisionError as e:
    print(e)
except ValueError as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'afdgs'

# %%
try:
    a=int(input("enter first number"))
    b=int(input("enter second number"))
    print(a/b)
except ZeroDivisionError as e:
    print(e)
except ValueError as e:
    print(e)

# %%
name ="Akankshaa"
number=10
name+number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 name ="Akankshaa"
#       2 number=10
# ----> 3 name+number
#       4
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
    print(lastname)
except NameError as e:
    print(e)
# Out:
# name 'lastname' is not defined

# %%
try:
    lst =[10,24,5,7,4,32,3]
    lst[12]
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    file= open("demo.txt",'r')
except FileNotFoundError as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'demo.txt'

# %%
try:
    num = int(input("enter your number"))
except ValueError as e:
    print("Invalid input",e)
else:
    print("your input",num)
# Out:
# Invalid input invalid literal for int() with base 10: 'huhfb'

# %%
try:

# %% [markdown]
# | Exception             | Description                            |
# | --------------------- | -------------------------------------- |
# | ZeroDivisionError   | Number ko 0 se divide karna            |
# | ValueError          | Wrong value type dena                  |
# | TypeError           | Different incompatible types use karna |
# | NameError           | Undefined variable use karna           |
# | IndexError          | Invalid list index access karna        |
# | KeyError            | Dictionary me missing key access karna |
# | FileNotFoundError   | File exist na karna                    |
# | AttributeError      | Invalid attribute/method access karna  |
# | ImportError         | Module import na hona                  |
# | ModuleNotFoundError | Module install na hona

# %%
age = -5
if age<0:
    raise Exception("age cannot be negative")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 age = -5
#       2 if age<0:
# ----> 3     raise Exception("age cannot be negative")
#
# Exception: age cannot be negative

# %%
name ="":
if name =="":
    raise Exception("name cannot be empty")
# Out:
#   Cell In[17], line 1
#     name ="":
#             ^
# SyntaxError: invalid syntax

# %%
try:
    age = -5
    if age<0:
        raise Exception("age cannot be negative")

# %%
class InvalidError(Exception):
    pass
age=15
if

# %%
class class_name(Exception):
    pass
try:
    bal =5000
    val=7000
    if val>bal:
        raise class_name("insufficeint balance")
    print("amount sent")
except class_name as e:
    print(e)
# Out:
# insufficeint balance

# %%
class pass_word(Exception):
    pass

try:
    password = "5903298"

    if len(password) != 6:
        raise pass_word("Password is of 6 digits")

    print("correct Password")

except pass_word as e:
    print(e)
# Out:
# Password is of 6 digits

# %%
class CapitalError(Exception):
    pass

class Check:
    def detect(self, ch):
        try:
